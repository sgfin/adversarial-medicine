# %%
import os
os.chdir("/home/sgf2/DBMI_server/adversarial_attacks/melanoma/")

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
from craft_attack_patch import *
from craft_attack_patch import _circle_mask
# Out:
# Using TensorFlow backend.

# %%
# Load images
image_path0 = './etc_saved_files_patch/non_cancer_mole.png'
image_path1 = './etc_saved_files_patch/cancer_mole.png'
im0 = load_image(image_path0, size = 299 * 4)
im1 = load_image(image_path1, size = 718)

# %%
# Load images
image_path0 = './etc_saved_files_patch/min_p_mole.png'
image_path1 = './etc_saved_files_patch/cancer_mole.png'
im0 = load_image(image_path0, size = 224)
im1 = load_image(image_path1, size = 718)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-4abb131d2b6b> in <module>()
#       2 image_path0 = './etc_saved_files_patch/min_p_mole.png'
#       3 image_path1 = './etc_saved_files_patch/cancer_mole.png'
# ----> 4 im0 = load_image(image_path0, size = 224)
#       5 im1 = load_image(image_path1, size = 718)
#
# /home/sgf2/Dropbox (MIT)/Documents/0 Research/0 Kohane/DBMI_server/adversarial_attacks/patch_attack/patch_derm_v2.py in load_image(image_path, size)
#      48   else:
#      49     ch = 3
# ---> 50   im = np.array(im.getdata()).reshape(im.size[0], im.size[1], ch)[:,:,:3]
#      51   return im / 127.5 - 1
#      52
#
# ValueError: cannot reshape array of size 150528 into shape (224,224,4)

# %%
crop0 = im0[115*4+1:190*4, 115*4+1:190*4,:]
show(crop0)
mole_patch0 = crop0 * _circle_mask(crop0.shape)
show(mole_patch0)

# %%
crop1 = im1[84:383, 240:539, :]
show(crop1)
mole_patch1 = crop1 * _circle_mask(crop1.shape)
show(mole_patch1)

# %%
# save the cropped mole 0
file_name0 = './etc_saved_files_patch/non_cancer_mole.npy'
np.save(file_name0, mole_patch0)

# %%
# save the cropped mole 1
file_name1 = './etc_saved_files_patch/cancer_mole.npy'
np.save(file_name1, mole_patch1)
